# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import warnings
#warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import seaborn as sns

# %%
data=pd.read_excel(r'C:\Users\Pardhu\OneDrive\Desktop\bank.xlsx',date_parser=True)

# %%
df=pd.DataFrame(data=data)

# %%
df.head()
# Out:
#       Account No       DATE               TRANSACTION DETAILS  CHQ.NO.  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES      NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES      NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE      NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES      NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE      NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .
# 0 2017-06-29             NaN    1000000.0    1000000.0  .
# 1 2017-07-05             NaN    1000000.0    2000000.0  .
# 2 2017-07-18             NaN     500000.0    2500000.0  .
# 3 2017-08-01             NaN    3000000.0    5500000.0  .
# 4 2017-08-16             NaN     500000.0    6000000.0  .

# %%
df.dtypes
# Out:
# Account No                     object
# DATE                   datetime64[ns]
# TRANSACTION DETAILS            object
# CHQ.NO.                       float64
# VALUE DATE             datetime64[ns]
# WITHDRAWAL AMT                float64
# DEPOSIT AMT                   float64
# BALANCE AMT                   float64
# .                              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Account No                  0
# DATE                        0
# TRANSACTION DETAILS      2499
# CHQ.NO.                115296
# VALUE DATE                  0
# WITHDRAWAL AMT          62652
# DEPOSIT AMT             53549
# BALANCE AMT                 0
# .                           0
# dtype: int64

# %%
df.describe()
# Out:
#              CHQ.NO.  WITHDRAWAL AMT   DEPOSIT AMT   BALANCE AMT
# count     905.000000    5.354900e+04  6.265200e+04  1.162010e+05
# mean   791614.503867    4.489190e+06  3.806586e+06 -1.404852e+09
# std    151205.932910    1.084850e+07  8.683093e+06  5.348202e+08
# min         1.000000    1.000000e-02  1.000000e-02 -2.045201e+09
# 25%    704231.000000    3.000000e+03  9.900000e+04 -1.690383e+09
# 50%    873812.000000    4.708300e+04  4.265000e+05 -1.661395e+09
# 75%    874167.000000    5.000000e+06  4.746411e+06 -1.236888e+09
# max    874525.000000    4.594475e+08  5.448000e+08  8.500000e+06

# %%
df.shape
# Out:
# (116201, 9)

# %%
df.columns
# Out:
# Index(['Account No', 'DATE', 'TRANSACTION DETAILS', 'CHQ.NO.', 'VALUE DATE',
#        'WITHDRAWAL AMT', 'DEPOSIT AMT', 'BALANCE AMT', '.'],
#       dtype='object')

# %%
df.rename(columns={'CHQ.NO.':'Chq_no'},inplace=True)

# %%
df.columns
# Out:
# Index(['Account No', 'DATE', 'TRANSACTION DETAILS', 'Chq_no', 'VALUE DATE',
#        'WITHDRAWAL AMT', 'DEPOSIT AMT', 'BALANCE AMT', '.'],
#       dtype='object')

# %%
df.head()
# Out:
#       Account No       DATE               TRANSACTION DETAILS  Chq_no  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES     NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES     NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE     NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES     NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE     NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .
# 0 2017-06-29             NaN    1000000.0    1000000.0  .
# 1 2017-07-05             NaN    1000000.0    2000000.0  .
# 2 2017-07-18             NaN     500000.0    2500000.0  .
# 3 2017-08-01             NaN    3000000.0    5500000.0  .
# 4 2017-08-16             NaN     500000.0    6000000.0  .

# %%
df['TRANSACTION DETAILS'].value_counts()
# Out:
# FDRL/INTERNAL FUND TRANSFE          8839
# FDRL/NATIONAL ELECTRONIC F          6262
# INTERNAL FUND TRANSFER IN           3262
# TRF TO  Indiaforensic SERVICES I    3082
# TRF FROM  Indiaforensic SERVICES    2107
#                                     ...
# IMPS 819721826786 FROM OX              1
# IMPS IW 22042016 1C                    1
# Indiaforensic MASTER ACQ DOM0101       1
# IMPS 030517 1C                         1
# IMPS 261017 4C                         1
# Name: TRANSACTION DETAILS, Length: 44806, dtype: int64

# %%
def year(data):
    data=data.year
    return data

# %%
def month(data):
    data=data.month
    return data

# %%
def day(data):
    data=data.day
    return data

# %%
df['Year']=df['DATE'].apply(year)
df['Month']=df['DATE'].apply(month)
df['Day']=df['DATE'].apply(day)

# %%
df.head()
# Out:
#       Account No       DATE               TRANSACTION DETAILS  Chq_no  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES     NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES     NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE     NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES     NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE     NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day
# 0 2017-06-29             NaN    1000000.0    1000000.0  .  2017      6   29
# 1 2017-07-05             NaN    1000000.0    2000000.0  .  2017      7    5
# 2 2017-07-18             NaN     500000.0    2500000.0  .  2017      7   18
# 3 2017-08-01             NaN    3000000.0    5500000.0  .  2017      8    1
# 4 2017-08-16             NaN     500000.0    6000000.0  .  2017      8   16

# %%
df['Value_Year']=df['VALUE DATE'].apply(year)
df['Value_Month']=df['VALUE DATE'].apply(month)
df['Value_Day']=df['VALUE DATE'].apply(day)

# %%
df.head()
# Out:
#       Account No       DATE               TRANSACTION DETAILS  Chq_no  \
# 0  409000611074' 2017-06-29  TRF FROM  Indiaforensic SERVICES     NaN
# 1  409000611074' 2017-07-05  TRF FROM  Indiaforensic SERVICES     NaN
# 2  409000611074' 2017-07-18        FDRL/INTERNAL FUND TRANSFE     NaN
# 3  409000611074' 2017-08-01   TRF FRM  Indiaforensic SERVICES     NaN
# 4  409000611074' 2017-08-16        FDRL/INTERNAL FUND TRANSFE     NaN
#
#   VALUE DATE  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day  \
# 0 2017-06-29             NaN    1000000.0    1000000.0  .  2017      6   29
# 1 2017-07-05             NaN    1000000.0    2000000.0  .  2017      7    5
# 2 2017-07-18             NaN     500000.0    2500000.0  .  2017      7   18
# 3 2017-08-01             NaN    3000000.0    5500000.0  .  2017      8    1
# 4 2017-08-16             NaN     500000.0    6000000.0  .  2017      8   16
#
#    Value_Year  Value_Month  Value_Day
# 0        2017            6         29
# ...

# %%
df.drop(columns=['DATE','VALUE DATE'],inplace=True)

# %%
df.head()
# Out:
#       Account No               TRANSACTION DETAILS  Chq_no  WITHDRAWAL AMT  \
# 0  409000611074'  TRF FROM  Indiaforensic SERVICES     NaN             NaN
# 1  409000611074'  TRF FROM  Indiaforensic SERVICES     NaN             NaN
# 2  409000611074'        FDRL/INTERNAL FUND TRANSFE     NaN             NaN
# 3  409000611074'   TRF FRM  Indiaforensic SERVICES     NaN             NaN
# 4  409000611074'        FDRL/INTERNAL FUND TRANSFE     NaN             NaN
#
#    DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day  Value_Year  Value_Month  \
# 0    1000000.0    1000000.0  .  2017      6   29        2017            6
# 1    1000000.0    2000000.0  .  2017      7    5        2017            7
# 2     500000.0    2500000.0  .  2017      7   18        2017            7
# 3    3000000.0    5500000.0  .  2017      8    1        2017            8
# 4     500000.0    6000000.0  .  2017      8   16        2017            8
#
#    Value_Day
# 0         29
# 1          5
# 2         18
# ...

# %%
df.fillna(0,inplace=True)

# %%
df.head()
# Out:
#       Account No               TRANSACTION DETAILS  Chq_no  WITHDRAWAL AMT  \
# 0  409000611074'  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 1  409000611074'  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 2  409000611074'        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
# 3  409000611074'   TRF FRM  Indiaforensic SERVICES     0.0             0.0
# 4  409000611074'        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
#
#    DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day  Value_Year  Value_Month  \
# 0    1000000.0    1000000.0  .  2017      6   29        2017            6
# 1    1000000.0    2000000.0  .  2017      7    5        2017            7
# 2     500000.0    2500000.0  .  2017      7   18        2017            7
# 3    3000000.0    5500000.0  .  2017      8    1        2017            8
# 4     500000.0    6000000.0  .  2017      8   16        2017            8
#
#    Value_Day
# 0         29
# 1          5
# 2         18
# ...

# %%
df['Account No'].dtype
# Out:
# dtype('O')

# %%
def convert(data):
    dat=data[:-1]
    return int(dat)

# %%
df['Account No']=df['Account No'].apply(convert)

# %%
df['Account No'].value_counts()
# Out:
# 1196428         48779
# 409000362497    29840
# 409000438620    13454
# 1196711         10536
# 409000493210     6014
# 409000438611     4588
# 409000611074     1093
# 409000493201     1044
# 409000425051      802
# 409000405747       51
# Name: Account No, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode=LabelEncoder()

# %%
df.head()
# Out:
#      Account No               TRANSACTION DETAILS  Chq_no  WITHDRAWAL AMT  \
# 0  409000611074  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 1  409000611074  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 2  409000611074        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
# 3  409000611074   TRF FRM  Indiaforensic SERVICES     0.0             0.0
# 4  409000611074        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
#
#    DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day  Value_Year  Value_Month  \
# 0    1000000.0    1000000.0  .  2017      6   29        2017            6
# 1    1000000.0    2000000.0  .  2017      7    5        2017            7
# 2     500000.0    2500000.0  .  2017      7   18        2017            7
# 3    3000000.0    5500000.0  .  2017      8    1        2017            8
# 4     500000.0    6000000.0  .  2017      8   16        2017            8
#
#    Value_Day
# 0         29
# 1          5
# 2         18
# 3          1
# ...

# %%
df['TRANSACTION DETAILS']=df['TRANSACTION DETAILS'].astype(str)

# %%
df['Trans_Details']=encode.fit_transform(df['TRANSACTION DETAILS'])

# %%
df.head()
# Out:
#      Account No               TRANSACTION DETAILS  Chq_no  WITHDRAWAL AMT  \
# 0  409000611074  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 1  409000611074  TRF FROM  Indiaforensic SERVICES     0.0             0.0
# 2  409000611074        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
# 3  409000611074   TRF FRM  Indiaforensic SERVICES     0.0             0.0
# 4  409000611074        FDRL/INTERNAL FUND TRANSFE     0.0             0.0
#
#    DEPOSIT AMT  BALANCE AMT  .  Year  Month  Day  Value_Year  Value_Month  \
# 0    1000000.0    1000000.0  .  2017      6   29        2017            6
# 1    1000000.0    2000000.0  .  2017      7    5        2017            7
# 2     500000.0    2500000.0  .  2017      7   18        2017            7
# 3    3000000.0    5500000.0  .  2017      8    1        2017            8
# 4     500000.0    6000000.0  .  2017      8   16        2017            8
#
#    Value_Day  Trans_Details
# 0         29          44503
# ...

# %%
df.drop(['TRANSACTION DETAILS'],axis=1,inplace=True)
df.drop(['.'],axis=1,inplace=True)
df.drop(['Account No'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Chq_no            float64
# WITHDRAWAL AMT    float64
# DEPOSIT AMT       float64
# BALANCE AMT       float64
# Year                int64
# Month               int64
# Day                 int64
# Value_Year          int64
# Value_Month         int64
# Value_Day           int64
# Trans_Details       int32
# dtype: object

# %%
df.head()
# Out:
#    Chq_no  WITHDRAWAL AMT  DEPOSIT AMT  BALANCE AMT  Year  Month  Day  \
# 0     0.0             0.0    1000000.0    1000000.0  2017      6   29
# 1     0.0             0.0    1000000.0    2000000.0  2017      7    5
# 2     0.0             0.0     500000.0    2500000.0  2017      7   18
# 3     0.0             0.0    3000000.0    5500000.0  2017      8    1
# 4     0.0             0.0     500000.0    6000000.0  2017      8   16
#
#    Value_Year  Value_Month  Value_Day  Trans_Details
# 0        2017            6         29          44503
# 1        2017            7          5          44503
# 2        2017            7         18          13891
# 3        2017            8          1          44494
# 4        2017            8         16          13891

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
new_df=scaler.fit_transform(df)

# %%
new_data=pd.DataFrame(data=new_df,columns=[df.columns])

# %%
new_data.head()
# Out:
#   Chq_no WITHDRAWAL AMT DEPOSIT AMT BALANCE AMT Year     Month       Day  \
# 0    0.0            0.0    0.001836    0.996348  0.5  0.454545  0.933333
# 1    0.0            0.0    0.001836    0.996835  0.5  0.545455  0.133333
# 2    0.0            0.0    0.000918    0.997078  0.5  0.545455  0.566667
# 3    0.0            0.0    0.005507    0.998539  0.5  0.636364  0.000000
# 4    0.0            0.0    0.000918    0.998783  0.5  0.636364  0.500000
#
#   Value_Year Value_Month Value_Day Trans_Details
# 0        0.5    0.454545  0.933333      0.993238
# 1        0.5    0.545455  0.133333      0.993238
# 2        0.5    0.545455  0.566667      0.310025
# 3        0.5    0.636364  0.000000      0.993037
# 4        0.5    0.636364  0.500000      0.310025

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=2)

# %%
km.fit(new_data)
# Out:
# KMeans(n_clusters=2)

# %%
km.labels_
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
target=pd.DataFrame(data=km.labels_,columns=['Target'])

# %%
pd.concat([new_data,target],axis=1)
# Out:
#         (Chq_no,)  (WITHDRAWAL AMT,)  (DEPOSIT AMT,)  (BALANCE AMT,)  (Year,)  \
# 0             0.0           0.000000        0.001836        0.996348      0.5
# 1             0.0           0.000000        0.001836        0.996835      0.5
# 2             0.0           0.000000        0.000918        0.997078      0.5
# 3             0.0           0.000000        0.005507        0.998539      0.5
# 4             0.0           0.000000        0.000918        0.998783      0.5
# ...           ...                ...             ...             ...      ...
# 116196        0.0           0.000257        0.000000        0.069776      1.0
# 116197        0.0           0.000000        0.000551        0.069922      1.0
# 116198        0.0           0.000000        0.000551        0.070068      1.0
# 116199        0.0           0.000239        0.000000        0.070015      1.0
# 116200        0.0           0.000011        0.000000        0.070012      1.0
#
# ...
